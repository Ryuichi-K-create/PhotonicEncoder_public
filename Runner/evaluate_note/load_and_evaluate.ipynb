# %%
import sys
import os
import numpy as np
sys.path.append(os.path.abspath("../")) 
from result_management.data_manager import create_result_pdf
from train.evaluate import plot_loss_curve, plot_errorbar_losscurve, plot_confusion_matrix, plot_histograms, create_table, convergence_verify, final_graph_maker
print("-------import finished-------")
#--------------------------------------------------------
experiment_name = 'Normal8191643'
variable_param = "leverage"  # 例: "alpha", "leverage", "none"
params={
    'dataset': 'covtype',  # 'mnist', 'cifar-10', 'cinic-10', 'fashion-mnist'
    'enc_type': 'PM',
    'cls_type': 'MLP',
    variable_param: [2,6,9,18,27,54],
    # 例: [1, 2, 4, 8, 16],[np.pi*2,np.pi, np.pi/2, np.pi/4, np.pi/8, np.pi/16]
    'num_try': 3,  # 試行回数
}

create_result_pdf(variable_param, params, experiment_name=experiment_name,Show=True)
# Out:
# -------import finished-------
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/2leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/2leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/2leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/2leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  73.294        4  75.434         3  69.188
# 1  LOSS   1.173        4   1.128         5   1.219
# 2  TIME  81.345        5  80.909         1  81.940
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/6leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/6leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/6leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/6leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  62.230        3  67.202         5  56.494
# 1  LOSS   1.426        3   1.316         5   1.547
# 2  TIME  80.773        5  80.187         2  81.140
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/9leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/9leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/9leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/9leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  54.205        3  56.077         4  52.634
# 1  LOSS   1.645        3   1.589         4   1.692
# 2  TIME  81.072        1  80.210         5  81.527
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/18leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/18leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/18leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/18leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  51.638        2  54.299         1  47.286
# 1  LOSS   1.765        2   1.647         1   1.854
# 2  TIME  81.112        1  81.002         3  81.419
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/27leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/27leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/27leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/27leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  47.760        1  48.366         4  46.397
# 1  LOSS   1.853        3   1.821         5   1.888
# 2  TIME  81.492        3  80.858         4  82.252
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/54leverage_1th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/54leverage_2th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/54leverage_3th_.csv
# Loading CSV file: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/54leverage_mid.csv
#         Average  Best ID    Best  Worst ID   Worst
# 0   ACC  48.380        3  50.891         4  46.755
# 1  LOSS   1.841        4   1.737         2   1.918
# 2  TIME  81.177        5  80.837         1  81.425
# PDFファイルを保存しました: /Users/konishi/Library/CloudStorage/OneDrive-個人用(2)/PhotonicEncoder_data/covtype/leverage_variable/PM/MLP/Normal8191643/experiment_report.pdf
