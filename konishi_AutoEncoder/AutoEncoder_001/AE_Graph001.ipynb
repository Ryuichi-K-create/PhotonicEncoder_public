# %%
#グラフを描画する

# %%
import csv
import os
import matplotlib.pyplot as plt
import numpy as np

home_directory = os.path.expanduser('~')
onedrive_folder_name = 'OneDrive'
onedrive_path = os.path.join(home_directory, onedrive_folder_name)
take_directory = os.path.join(onedrive_path,'CODES', 'konishi_AutoEncoder', 'AutoEncoder_data','texts')

# %%
#10/08

file_name1 = 'AE[5_]_list.csv'##
full_path1 = os.path.join(take_directory, file_name1)

# CSVファイルからデータを読み込む
list1_1 = []
list1_2 = []

with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list1_1 = list(map(float, next(reader)))
    list1_2 = list(map(float, next(reader)))
    list1_1 = list1_1[::-1]
    list1_2 = list1_2[::-1]


file_name2 = 'AE[3_]_list.csv'##
full_path2 = os.path.join(take_directory, file_name2)

# CSVファイルからデータを読み込む
list2_1 = []
list2_2 = []

with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list2_1 = list(map(float, next(reader)))
    list2_2 = list(map(float, next(reader)))
    list2_1 = list2_1[::-1]
    list2_2 = list2_2[::-1]

# グラフを描画

x_values = [x / 784 for x in range(len(list1_1))] 

plt.plot(x_values, list1_1, label='Complex Encoder:Train',color = 'cyan')
plt.plot(x_values, list1_2, label='Complex Encoder:Test',color = 'blue')

plt.plot(x_values, list2_1, label='Real Encoder:Train',color = 'red')
plt.plot(x_values, list2_2, label='Real Encoder:Test',color = 'orange')
plt.xlabel('N/M')
plt.ylabel('MSE')
plt.xlim(0,1)
plt.title('MSE Transition')
plt.legend()
plt.show()

# %%
#11/27

file_name1 = 'AE[7-1]_repList.csv'##
full_path1 = os.path.join(take_directory, file_name1)

# CSVファイルからデータを読み込む
list1_1 = []
list1_2 = []

with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list1_1 = list(map(float, next(reader)))
    list1_2 = list(map(float, next(reader)))
    list1_1 = list1_1[::-1]
    list1_2 = list1_2[::-1]


file_name2 = 'AE[7-1]_rep3List.csv'##
full_path2 = os.path.join(take_directory, file_name2)

# CSVファイルからデータを読み込む
list2_1 = []
list2_2 = []

with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list2_1 = list(map(float, next(reader)))
    list2_2 = list(map(float, next(reader)))
    list2_1 = list2_1[::-1]
    list2_2 = list2_2[::-1]


file_name3 = 'AE[7-1$]_repList.csv'##
full_path3 = os.path.join(take_directory, file_name3)

# CSVファイルからデータを読み込む
list3_1 = []
list3_2 = []

with open(full_path3, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list3_1 = list(map(float, next(reader)))
    list3_2 = list(map(float, next(reader)))
    list3_1 = list3_1[::-1]
    list3_2 = list3_2[::-1]

# グラフを描画
DofIN = 784
width = 8

desired_ratios = ["1:1", "1:2", "1:4", "1:8","1:16"]
desired_N_values = [DofIN // int(ratio.split(":")[1]) for ratio in desired_ratios]
desired_N_values = [DofIN - value for value in desired_N_values]
x_values = np.arange(DofIN, 0, -width)#[::-1]

#plt.plot(x_values, list1_1, label='Complex Encoder:Train',color = 'cyan')
plt.plot(x_values, list3_2, label='1-layer Encoder', color='green')
plt.plot(x_values, list1_2, label='2-layer Encoder', color='blue')
plt.plot(x_values, list2_2, label='3-layer Encoder', color='red')
plt.ylabel('MSE')
plt.xticks(
    ticks=desired_N_values,  # 目盛りを反転
    labels=desired_ratios   # ラベルを反転
)
plt.title('MSE Transition')
plt.legend()
plt.show()


plt.plot(x_values, list3_1, label='1-layer Encoder',color = 'green')

plt.plot(x_values, list1_1, label='2-layer Encoder',color = 'blue')

plt.plot(x_values, list2_1, label='3-layer Encoder',color = 'red')
plt.xlabel('N:M')
plt.ylabel('SSIM')
plt.xticks(ticks=desired_N_values, labels=desired_ratios)
plt.title('SSIM Transition')
plt.legend()
plt.show()

# %%
#10/07

file_name1 = 'AE[3^2]_list.csv'##
full_path1 = os.path.join(take_directory, file_name1)

# CSVファイルからデータを読み込む
list1_1 = []
list1_2 = []

with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list1_1 = list(map(float, next(reader)))
    list1_2 = list(map(float, next(reader)))
    list1_1 = list1_1[::-1]
    list1_2 = list1_2[::-1]


file_name2 = 'AE[4]_list.csv'##
full_path2 = os.path.join(take_directory, file_name2)

# CSVファイルからデータを読み込む
list2_1 = []
list2_2 = []

with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list2_1 = list(map(float, next(reader)))
    list2_2 = list(map(float, next(reader)))
    list2_1 = list2_1[::-1]
    list2_2 = list2_2[::-1]

# グラフを描画

x_values = [x / 784 for x in range(len(list1_1))] 

plt.plot(x_values, list1_1, label='Real Encoder:Train',color = 'cyan')
plt.plot(x_values, list1_2, label='Real Encoder:Test',color = 'blue')

plt.plot(x_values, list2_1, label='Complex Encoder:Train',color = 'red')
plt.plot(x_values, list2_2, label='Complex Encoder:Test',color = 'orange')
plt.xlabel('N/M')
plt.ylabel('MSE')
plt.xlim(0,1)
plt.title('MSE Transition')
plt.legend()
plt.show()

plt.plot(x_values, list1_1, label='Real Encoder:Train',color = 'cyan')
plt.plot(x_values, list1_2, label='Real Encoder:Test',color = 'blue')

plt.plot(x_values, list2_1, label='Complex Encoder:Train',color = 'red')
plt.plot(x_values, list2_2, label='Complex Encoder:Test',color = 'orange')
plt.xlabel('N/M')
plt.ylabel('MSE')
plt.xlim(0,1)
plt.ylim(0.0,0.015)
plt.title('MSE Transition')
plt.legend()
plt.show()

# %%
#11/24_ssim

file_name1 = 'AE[2_ssim]_lis.csv'##
full_path1 = os.path.join(take_directory, file_name1)

# CSVファイルからデータを読み込む
list1 = []

with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    # 各行をリストに格納
    list1 = list(map(float, next(reader)))


file_name2 = 'AE[5_ssim]_lis.csv'##
full_path2 = os.path.join(take_directory, file_name2)
list2 = []
with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    list2 = list(map(float, next(reader)))

'''
file_name3 = 'AE[7]_lis.csv'##
full_path3 = os.path.join(take_directory, file_name3)
list3 = []
with open(full_path3, mode='r') as file:
    reader = csv.reader(file)
    list3 = list(map(float, next(reader)))
'''

file_name4 = 'AE[2^2_ssim]_lis.csv'##
full_path4 = os.path.join(take_directory, file_name4)
list4 = []
with open(full_path4, mode='r') as file:
    reader = csv.reader(file)
    list4 = list(map(float, next(reader)))


x_values = range(1,51)

plt.plot(x_values, list1, label='RealEncoder',color = 'blue')

plt.plot(x_values, list2, label='PhaseComplexEncoder',color = 'red')

'''
plt.plot(x_values, list3, label='PhaseComplexEncoder(multi)',color = 'green')
'''
plt.plot(x_values, list4, label='RealEncoder(PD)',color = 'green')


plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.xlim(0,51)
plt.ylim(0.6,1)
plt.title('SSIM Transition:784→128→784')
plt.legend()
plt.show()


x_values = range(1,51)

plt.plot(x_values, list1, label='RealEncoder',color = 'blue')

plt.plot(x_values, list2, label='PhaseComplexEncoder',color = 'red')

plt.plot(x_values, list4, label='RealEncoder(PD)',color = 'green')


plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.xlim(0,31)
plt.ylim(0.7,0.95)
plt.title('SSIM Transition:784→128→784')
plt.legend()
plt.show()

# %%
#10/16

file_name1 = 'AE[√5_]_lis.csv'##
full_path1 = os.path.join(take_directory, file_name1)

list1 = []
with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    list1 = list(map(float, next(reader)))


file_name2 = 'AE[5_]_lis.csv'##
full_path2 = os.path.join(take_directory, file_name2)
list2 = []
with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    list2 = list(map(float, next(reader)))


x_values = range(1,11)

plt.plot(x_values, list1, label='PhaseComplexEncoder(√)',color = 'blue')

plt.plot(x_values, list2, label='PhaseComplexEncoder',color = 'red')


plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.xlim(0,11)
plt.title('MSE Transition:784→128→784')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 24
#      20 x_values = range(1,11)
#      22 plt.plot(x_values, list1, label='PhaseComplexEncoder(√)',color = 'blue')
# ---> 24 plt.plot(x_values, list2, label='PhaseComplexEncoder',color = 'red')
#      27 plt.xlabel('Epoch')
#      28 plt.ylabel('MSE')
#
# File c:\Users\Scent\anaconda3\envs\CENT002\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...

# %%
#10/16

file_name1 = 'AE[√3]_lis.csv'##
full_path1 = os.path.join(take_directory, file_name1)

list1 = []
with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    list1 = list(map(float, next(reader)))


file_name2 = 'AE[2^2]_lis.csv'##
full_path2 = os.path.join(take_directory, file_name2)
list2 = []
with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    list2 = list(map(float, next(reader)))


x_values = range(1,11)

plt.plot(x_values, list1, label='RealEncoder(√)',color = 'blue')

plt.plot(x_values, list2, label='RealEncoder',color = 'red')
file_name1 = 'AE[√5_]_lis.csv'##
full_path1 = os.path.join(take_directory, file_name1)

list1 = []
with open(full_path1, mode='r') as file:
    reader = csv.reader(file)
    list1 = list(map(float, next(reader)))


file_name2 = 'AE[5_]_lis.csv'##
full_path2 = os.path.join(take_directory, file_name2)
list2 = []
with open(full_path2, mode='r') as file:
    reader = csv.reader(file)
    list2 = list(map(float, next(reader)))


x_values = range(1,11)

plt.plot(x_values, list1, label='PhaseComplexEncoder(√)',color = 'green')

plt.plot(x_values, list2, label='PhaseComplexEncoder',color = 'yellow')

plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.xlim(0,11)
plt.title('MSE Transition:784→128→784')
plt.legend()
plt.show()
